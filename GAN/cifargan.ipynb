# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
import os
from PIL import Image
from torchvision.transforms import ToPILImage

# %%
class Discriminator(nn.Module):
    def __init__(self):
        super().__init__()
        self.disc = nn.Sequential(
            nn.Linear(3 * 64 * 64, 512),
            nn.LeakyReLU(0.2),
            nn.Linear(512, 256),
            nn.LeakyReLU(0.2),
            nn.Linear(256, 1),
            nn.Sigmoid(),
        )

    def forward(self, img):
        return self.disc(img)

# %%
class Generator(nn.Module):
    def __init__(self, z_dim):
        super().__init__()
        self.gen = nn.Sequential(
            nn.Linear(z_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 256),
            nn.ReLU(),
            nn.Linear(256, 512),
            nn.ReLU(),
            nn.Linear(512, 3 * 64 * 64),  # For 64x64 RGB images
            nn.Tanh(),
        )

    def forward(self, noise):
        return self.gen(noise)

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# Hyperparameters
lr = 1e-4
z_dim = 100  # Latent vector dimension
image_dim = 3 * 64 * 64  # 3 (RGB) x 64 x 64
batch_size = 32
epochs = 200

# %%
disc = Discriminator().to(device)
gen = Generator(z_dim).to(device)
fixed_noise = torch.randn((1, z_dim)).to(device)  # Single noise vector for generating images

# Image transformations
transforms = transforms.Compose([
    transforms.Resize((64, 64)),            # Resize images to 64x64
    transforms.ToTensor(),                 # Convert to tensor
    transforms.Normalize([0.5], [0.5]),    # Normalize to [-1, 1]
])

# %%
dataset_path = "anime"  # Path to your cat image folder


# Load dataset
dataset = ImageFolder(root=dataset_path, transform=transforms)
loader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

opt_disc = optim.Adam(disc.parameters(), lr=lr)
opt_gen = optim.Adam(gen.parameters(), lr=lr)
criterion = nn.BCELoss()

output_dir = "generatedimages"
os.makedirs(output_dir, exist_ok=True)

# %%
to_pil = ToPILImage()
for epoch in range(epochs):
    for batch_idx, (real, _) in enumerate(loader):
        real = real.view(-1, 3 * 64 * 64).to(device)  # Flatten images
        batch_size = real.shape[0]

        # Train Discriminator
        noise = torch.randn(batch_size, z_dim).to(device)
        fake = gen(noise)
        disc_real = disc(real).view(-1)
        lossD_real = criterion(disc_real, torch.ones_like(disc_real))
        disc_fake = disc(fake.detach()).view(-1)
        lossD_fake = criterion(disc_fake, torch.zeros_like(disc_fake))
        lossD = (lossD_real + lossD_fake) / 2
        disc.zero_grad()
        lossD.backward()
        opt_disc.step()

        # Train Generator
        output = disc(fake).view(-1)
        lossG = criterion(output, torch.ones_like(output))
        gen.zero_grad()
        lossG.backward()
        opt_gen.step()

        # Logging and saving images
        if batch_idx % 50 == 0:  # Save image every 50 batches
            print(
                f"Epoch [{epoch}/{epochs}] Batch {batch_idx}/{len(loader)} \
                Loss D: {lossD:.4f}, Loss G: {lossG:.4f}"
            )

            with torch.no_grad():
                # Generate a single image using fixed noise
                fake_image = gen(fixed_noise).reshape(3, 64, 64)  # Reshape to (C, H, W)
                fake_image = (fake_image * 0.5 + 0.5).clamp(0, 1)  # Denormalize to [0, 1]

                # Convert to PIL image and save
                pil_image = to_pil(fake_image.cpu())
                image_path = os.path.join(output_dir, f"epoch_{epoch}_batch_{batch_idx}.png")
                pil_image.save(image_path)
                print(f"Saved image: {image_path}")
# Out:
# Epoch [0/200] Batch 0/1987                 Loss D: 0.6810, Loss G: 0.7293
# Saved image: generatedimages\epoch_0_batch_0.png
# Epoch [0/200] Batch 50/1987                 Loss D: 0.2665, Loss G: 1.4079
# Saved image: generatedimages\epoch_0_batch_50.png
# Epoch [0/200] Batch 100/1987                 Loss D: 0.0872, Loss G: 2.1639
# Saved image: generatedimages\epoch_0_batch_100.png
# Epoch [0/200] Batch 150/1987                 Loss D: 0.0625, Loss G: 2.7898
# Saved image: generatedimages\epoch_0_batch_150.png
# Epoch [0/200] Batch 200/1987                 Loss D: 0.0428, Loss G: 2.9132
# Saved image: generatedimages\epoch_0_batch_200.png
# Epoch [0/200] Batch 250/1987                 Loss D: 0.0531, Loss G: 2.5435
# Saved image: generatedimages\epoch_0_batch_250.png
# Epoch [0/200] Batch 300/1987                 Loss D: 0.1270, Loss G: 1.9026
# Saved image: generatedimages\epoch_0_batch_300.png
# Epoch [0/200] Batch 350/1987                 Loss D: 0.0897, Loss G: 2.7505
# Saved image: generatedimages\epoch_0_batch_350.png
# Epoch [0/200] Batch 400/1987                 Loss D: 0.1078, Loss G: 2.4415
# Saved image: generatedimages\epoch_0_batch_400.png
# Epoch [0/200] Batch 450/1987                 Loss D: 0.0061, Loss G: 5.2482
# Saved image: generatedimages\epoch_0_batch_450.png
# Epoch [0/200] Batch 500/1987                 Loss D: 0.1308, Loss G: 1.8557
# Saved image: generatedimages\epoch_0_batch_500.png
# Epoch [0/200] Batch 550/1987                 Loss D: 0.0573, Loss G: 3.7017
# Saved image: generatedimages\epoch_0_batch_550.png
# Epoch [0/200] Batch 600/1987                 Loss D: 0.0447, Loss G: 3.9819
# Saved image: generatedimages\epoch_0_batch_600.png
# Epoch [0/200] Batch 650/1987                 Loss D: 0.1157, Loss G: 2.4923
# Saved image: generatedimages\epoch_0_batch_650.png
# Epoch [0/200] Batch 700/1987                 Loss D: 0.3858, Loss G: 1.4711
# Saved image: generatedimages\epoch_0_batch_700.png
# Epoch [0/200] Batch 750/1987                 Loss D: 0.1441, Loss G: 2.2268
# Saved image: generatedimages\epoch_0_batch_750.png
# Epoch [0/200] Batch 800/1987                 Loss D: 0.0833, Loss G: 3.3378
# Saved image: generatedimages\epoch_0_batch_800.png
# Epoch [0/200] Batch 850/1987                 Loss D: 0.0337, Loss G: 3.4629
# Saved image: generatedimages\epoch_0_batch_850.png
# Epoch [0/200] Batch 900/1987                 Loss D: 0.0230, Loss G: 3.8584
# Saved image: generatedimages\epoch_0_batch_900.png
# Epoch [0/200] Batch 950/1987                 Loss D: 0.0746, Loss G: 2.2470
# Saved image: generatedimages\epoch_0_batch_950.png
# Epoch [0/200] Batch 1000/1987                 Loss D: 0.0681, Loss G: 3.6757
# Saved image: generatedimages\epoch_0_batch_1000.png
# Epoch [0/200] Batch 1050/1987                 Loss D: 0.0170, Loss G: 4.6296
# Saved image: generatedimages\epoch_0_batch_1050.png
# Epoch [0/200] Batch 1100/1987                 Loss D: 0.0325, Loss G: 3.7769
# Saved image: generatedimages\epoch_0_batch_1100.png
# Epoch [0/200] Batch 1150/1987                 Loss D: 0.0023, Loss G: 6.9514
# Saved image: generatedimages\epoch_0_batch_1150.png
# Epoch [0/200] Batch 1200/1987                 Loss D: 0.1633, Loss G: 2.1972
# Saved image: generatedimages\epoch_0_batch_1200.png
# Epoch [0/200] Batch 1250/1987                 Loss D: 0.0675, Loss G: 3.5681
# Saved image: generatedimages\epoch_0_batch_1250.png
# Epoch [0/200] Batch 1300/1987                 Loss D: 0.0039, Loss G: 6.0784
# Saved image: generatedimages\epoch_0_batch_1300.png
# Epoch [0/200] Batch 1350/1987                 Loss D: 0.0284, Loss G: 4.5451
# Saved image: generatedimages\epoch_0_batch_1350.png
# Epoch [0/200] Batch 1400/1987                 Loss D: 0.0412, Loss G: 5.3294
# Saved image: generatedimages\epoch_0_batch_1400.png
# Epoch [0/200] Batch 1450/1987                 Loss D: 0.0373, Loss G: 4.9879
# Saved image: generatedimages\epoch_0_batch_1450.png
# Epoch [0/200] Batch 1500/1987                 Loss D: 0.0698, Loss G: 4.4212
# Saved image: generatedimages\epoch_0_batch_1500.png
# Epoch [0/200] Batch 1550/1987                 Loss D: 0.1412, Loss G: 6.0848
# Saved image: generatedimages\epoch_0_batch_1550.png
# Epoch [0/200] Batch 1600/1987                 Loss D: 0.0631, Loss G: 4.0372
# Saved image: generatedimages\epoch_0_batch_1600.png
# Epoch [0/200] Batch 1650/1987                 Loss D: 0.0113, Loss G: 4.8064
# Saved image: generatedimages\epoch_0_batch_1650.png
# Epoch [0/200] Batch 1700/1987                 Loss D: 0.0303, Loss G: 5.6159
# Saved image: generatedimages\epoch_0_batch_1700.png
# Epoch [0/200] Batch 1750/1987                 Loss D: 0.1429, Loss G: 2.6530
# Saved image: generatedimages\epoch_0_batch_1750.png
# Epoch [0/200] Batch 1800/1987                 Loss D: 0.0013, Loss G: 6.6360
# Saved image: generatedimages\epoch_0_batch_1800.png
# Epoch [0/200] Batch 1850/1987                 Loss D: 0.0708, Loss G: 2.3309
# Saved image: generatedimages\epoch_0_batch_1850.png
# Epoch [0/200] Batch 1900/1987                 Loss D: 0.0347, Loss G: 3.8774
# Saved image: generatedimages\epoch_0_batch_1900.png
# Epoch [0/200] Batch 1950/1987                 Loss D: 0.0135, Loss G: 6.9761
# Saved image: generatedimages\epoch_0_batch_1950.png
# Epoch [1/200] Batch 0/1987                 Loss D: 0.0093, Loss G: 7.8668
# Saved image: generatedimages\epoch_1_batch_0.png
# Epoch [1/200] Batch 50/1987                 Loss D: 0.0081, Loss G: 6.3643
# Saved image: generatedimages\epoch_1_batch_50.png
# Epoch [1/200] Batch 100/1987                 Loss D: 0.0789, Loss G: 5.7679
# Saved image: generatedimages\epoch_1_batch_100.png
# Epoch [1/200] Batch 150/1987                 Loss D: 0.0846, Loss G: 4.1010
# Saved image: generatedimages\epoch_1_batch_150.png
# Epoch [1/200] Batch 200/1987                 Loss D: 0.0931, Loss G: 6.1847
# Saved image: generatedimages\epoch_1_batch_200.png
# Epoch [1/200] Batch 250/1987                 Loss D: 0.0422, Loss G: 7.4098
# Saved image: generatedimages\epoch_1_batch_250.png
# Epoch [1/200] Batch 300/1987                 Loss D: 0.0941, Loss G: 3.8581
# Saved image: generatedimages\epoch_1_batch_300.png
# Epoch [1/200] Batch 350/1987                 Loss D: 0.0142, Loss G: 5.6175
# Saved image: generatedimages\epoch_1_batch_350.png
# Epoch [1/200] Batch 400/1987                 Loss D: 0.0221, Loss G: 6.0608
# Saved image: generatedimages\epoch_1_batch_400.png
# Epoch [1/200] Batch 450/1987                 Loss D: 0.0018, Loss G: 7.7493
# Saved image: generatedimages\epoch_1_batch_450.png
# Epoch [1/200] Batch 500/1987                 Loss D: 0.0288, Loss G: 7.2011
# Saved image: generatedimages\epoch_1_batch_500.png
# Epoch [1/200] Batch 550/1987                 Loss D: 0.0065, Loss G: 5.1660
# Saved image: generatedimages\epoch_1_batch_550.png
# Epoch [1/200] Batch 600/1987                 Loss D: 0.0032, Loss G: 7.6910
# Saved image: generatedimages\epoch_1_batch_600.png
# Epoch [1/200] Batch 650/1987                 Loss D: 0.0632, Loss G: 4.2296
# Saved image: generatedimages\epoch_1_batch_650.png
# Epoch [1/200] Batch 700/1987                 Loss D: 0.0634, Loss G: 6.3213
# Saved image: generatedimages\epoch_1_batch_700.png
# Epoch [1/200] Batch 750/1987                 Loss D: 0.0269, Loss G: 4.2229
# Saved image: generatedimages\epoch_1_batch_750.png
# Epoch [1/200] Batch 800/1987                 Loss D: 0.0112, Loss G: 5.5785
# Saved image: generatedimages\epoch_1_batch_800.png
# Epoch [1/200] Batch 850/1987                 Loss D: 0.1591, Loss G: 9.1010
# Saved image: generatedimages\epoch_1_batch_850.png
# Epoch [1/200] Batch 900/1987                 Loss D: 0.1401, Loss G: 4.4300
# Saved image: generatedimages\epoch_1_batch_900.png
# Epoch [1/200] Batch 950/1987                 Loss D: 0.0173, Loss G: 5.3660
# Saved image: generatedimages\epoch_1_batch_950.png
# Epoch [1/200] Batch 1000/1987                 Loss D: 0.0223, Loss G: 4.3898
# Saved image: generatedimages\epoch_1_batch_1000.png
# Epoch [1/200] Batch 1050/1987                 Loss D: 0.0557, Loss G: 6.1410
# Saved image: generatedimages\epoch_1_batch_1050.png
# Epoch [1/200] Batch 1100/1987                 Loss D: 0.0454, Loss G: 5.2506
# Saved image: generatedimages\epoch_1_batch_1100.png
# Epoch [1/200] Batch 1150/1987                 Loss D: 0.1043, Loss G: 7.1708
# Saved image: generatedimages\epoch_1_batch_1150.png
# Epoch [1/200] Batch 1200/1987                 Loss D: 0.0316, Loss G: 3.8386
# Saved image: generatedimages\epoch_1_batch_1200.png
# Epoch [1/200] Batch 1250/1987                 Loss D: 0.0039, Loss G: 5.8658
# Saved image: generatedimages\epoch_1_batch_1250.png
# Epoch [1/200] Batch 1300/1987                 Loss D: 0.0562, Loss G: 7.4751
# Saved image: generatedimages\epoch_1_batch_1300.png
# Epoch [1/200] Batch 1350/1987                 Loss D: 0.0043, Loss G: 6.7599
# Saved image: generatedimages\epoch_1_batch_1350.png
# Epoch [1/200] Batch 1400/1987                 Loss D: 0.0067, Loss G: 7.0059
# Saved image: generatedimages\epoch_1_batch_1400.png
# Epoch [1/200] Batch 1450/1987                 Loss D: 0.3884, Loss G: 5.8605
# Saved image: generatedimages\epoch_1_batch_1450.png
# Epoch [1/200] Batch 1500/1987                 Loss D: 0.0195, Loss G: 5.6653
# Saved image: generatedimages\epoch_1_batch_1500.png
# Epoch [1/200] Batch 1550/1987                 Loss D: 0.0121, Loss G: 6.0084
# Saved image: generatedimages\epoch_1_batch_1550.png
# Epoch [1/200] Batch 1600/1987                 Loss D: 0.0301, Loss G: 7.1283
# Saved image: generatedimages\epoch_1_batch_1600.png
# Epoch [1/200] Batch 1650/1987                 Loss D: 0.0186, Loss G: 5.1801
# Saved image: generatedimages\epoch_1_batch_1650.png
# Epoch [1/200] Batch 1700/1987                 Loss D: 0.0026, Loss G: 8.7523
# Saved image: generatedimages\epoch_1_batch_1700.png
# Epoch [1/200] Batch 1750/1987                 Loss D: 0.0009, Loss G: 9.4044
# Saved image: generatedimages\epoch_1_batch_1750.png
# Epoch [1/200] Batch 1800/1987                 Loss D: 0.0194, Loss G: 7.4401
# Saved image: generatedimages\epoch_1_batch_1800.png
# Epoch [1/200] Batch 1850/1987                 Loss D: 0.0171, Loss G: 5.0671
# Saved image: generatedimages\epoch_1_batch_1850.png
# Epoch [1/200] Batch 1900/1987                 Loss D: 0.0074, Loss G: 5.2407
# Saved image: generatedimages\epoch_1_batch_1900.png
# Epoch [1/200] Batch 1950/1987                 Loss D: 0.0288, Loss G: 4.5920
# Saved image: generatedimages\epoch_1_batch_1950.png
# Epoch [2/200] Batch 0/1987                 Loss D: 0.0479, Loss G: 3.8583
# Saved image: generatedimages\epoch_2_batch_0.png
# Epoch [2/200] Batch 50/1987                 Loss D: 0.0136, Loss G: 4.6535
# Saved image: generatedimages\epoch_2_batch_50.png
# Epoch [2/200] Batch 100/1987                 Loss D: 0.0634, Loss G: 1.6049
# Saved image: generatedimages\epoch_2_batch_100.png
# Epoch [2/200] Batch 150/1987                 Loss D: 0.0196, Loss G: 5.0122
# Saved image: generatedimages\epoch_2_batch_150.png
# Epoch [2/200] Batch 200/1987                 Loss D: 0.0536, Loss G: 7.0514
# Saved image: generatedimages\epoch_2_batch_200.png
# Epoch [2/200] Batch 250/1987                 Loss D: 0.0955, Loss G: 5.7061
# Saved image: generatedimages\epoch_2_batch_250.png
# Epoch [2/200] Batch 300/1987                 Loss D: 0.0115, Loss G: 5.3802
# Saved image: generatedimages\epoch_2_batch_300.png
# Epoch [2/200] Batch 350/1987                 Loss D: 0.0440, Loss G: 7.2352
# Saved image: generatedimages\epoch_2_batch_350.png
# Epoch [2/200] Batch 400/1987                 Loss D: 0.2344, Loss G: 5.5098
# Saved image: generatedimages\epoch_2_batch_400.png
# Epoch [2/200] Batch 450/1987                 Loss D: 0.0057, Loss G: 6.2143
# Saved image: generatedimages\epoch_2_batch_450.png
# Epoch [2/200] Batch 500/1987                 Loss D: 0.1264, Loss G: 7.6360
# Saved image: generatedimages\epoch_2_batch_500.png
# Epoch [2/200] Batch 550/1987                 Loss D: 0.0420, Loss G: 13.2776
# Saved image: generatedimages\epoch_2_batch_550.png
# Epoch [2/200] Batch 600/1987                 Loss D: 0.7970, Loss G: 7.0663
# Saved image: generatedimages\epoch_2_batch_600.png
# Epoch [2/200] Batch 650/1987                 Loss D: 0.0469, Loss G: 5.1728
# Saved image: generatedimages\epoch_2_batch_650.png
# Epoch [2/200] Batch 700/1987                 Loss D: 0.0013, Loss G: 7.4787
# Saved image: generatedimages\epoch_2_batch_700.png
# Epoch [2/200] Batch 750/1987                 Loss D: 0.0077, Loss G: 6.2938
# Saved image: generatedimages\epoch_2_batch_750.png
# Epoch [2/200] Batch 800/1987                 Loss D: 0.2008, Loss G: 4.4553
# Saved image: generatedimages\epoch_2_batch_800.png
# Epoch [2/200] Batch 850/1987                 Loss D: 0.0075, Loss G: 5.1209
# Saved image: generatedimages\epoch_2_batch_850.png
# Epoch [2/200] Batch 900/1987                 Loss D: 0.0148, Loss G: 6.7499
# Saved image: generatedimages\epoch_2_batch_900.png
# Epoch [2/200] Batch 950/1987                 Loss D: 0.0128, Loss G: 5.0768
# Saved image: generatedimages\epoch_2_batch_950.png
# Epoch [2/200] Batch 1000/1987                 Loss D: 0.0776, Loss G: 15.6928
# Saved image: generatedimages\epoch_2_batch_1000.png
# Epoch [2/200] Batch 1050/1987                 Loss D: 0.0322, Loss G: 4.5430
# Saved image: generatedimages\epoch_2_batch_1050.png
# Epoch [2/200] Batch 1100/1987                 Loss D: 0.1673, Loss G: 4.3407
# Saved image: generatedimages\epoch_2_batch_1100.png
# Epoch [2/200] Batch 1150/1987                 Loss D: 0.0062, Loss G: 6.3527
# Saved image: generatedimages\epoch_2_batch_1150.png
# Epoch [2/200] Batch 1200/1987                 Loss D: 0.0019, Loss G: 8.1021
# Saved image: generatedimages\epoch_2_batch_1200.png
# Epoch [2/200] Batch 1250/1987                 Loss D: 0.0036, Loss G: 10.9772
# Saved image: generatedimages\epoch_2_batch_1250.png
# Epoch [2/200] Batch 1300/1987                 Loss D: 0.1461, Loss G: 4.3082
# Saved image: generatedimages\epoch_2_batch_1300.png
# Epoch [2/200] Batch 1350/1987                 Loss D: 0.0031, Loss G: 8.4093
# Saved image: generatedimages\epoch_2_batch_1350.png
# Epoch [2/200] Batch 1400/1987                 Loss D: 0.0330, Loss G: 5.5826
# Saved image: generatedimages\epoch_2_batch_1400.png
# Epoch [2/200] Batch 1450/1987                 Loss D: 0.1906, Loss G: 6.9298
# Saved image: generatedimages\epoch_2_batch_1450.png
# Epoch [2/200] Batch 1500/1987                 Loss D: 0.1336, Loss G: 8.3310
# Saved image: generatedimages\epoch_2_batch_1500.png
# Epoch [2/200] Batch 1550/1987                 Loss D: 0.0005, Loss G: 7.0773
# Saved image: generatedimages\epoch_2_batch_1550.png
# Epoch [2/200] Batch 1600/1987                 Loss D: 0.3200, Loss G: 4.8161
# Saved image: generatedimages\epoch_2_batch_1600.png
# Epoch [2/200] Batch 1650/1987                 Loss D: 0.0012, Loss G: 6.1163
# Saved image: generatedimages\epoch_2_batch_1650.png
# Epoch [2/200] Batch 1700/1987                 Loss D: 0.0553, Loss G: 5.4168
# Saved image: generatedimages\epoch_2_batch_1700.png
# Epoch [2/200] Batch 1750/1987                 Loss D: 0.0161, Loss G: 5.1138
# Saved image: generatedimages\epoch_2_batch_1750.png
# Epoch [2/200] Batch 1800/1987                 Loss D: 0.0289, Loss G: 3.1858
# Saved image: generatedimages\epoch_2_batch_1800.png
# Epoch [2/200] Batch 1850/1987                 Loss D: 0.0576, Loss G: 6.2996
# Saved image: generatedimages\epoch_2_batch_1850.png
# Epoch [2/200] Batch 1900/1987                 Loss D: 0.1109, Loss G: 4.6241
# Saved image: generatedimages\epoch_2_batch_1900.png
# Epoch [2/200] Batch 1950/1987                 Loss D: 0.1903, Loss G: 5.0067
# Saved image: generatedimages\epoch_2_batch_1950.png
# Epoch [3/200] Batch 0/1987                 Loss D: 0.0238, Loss G: 5.4202
# Saved image: generatedimages\epoch_3_batch_0.png
# Epoch [3/200] Batch 50/1987                 Loss D: 0.0061, Loss G: 6.4558
# Saved image: generatedimages\epoch_3_batch_50.png
# Epoch [3/200] Batch 100/1987                 Loss D: 0.0186, Loss G: 5.1765
# Saved image: generatedimages\epoch_3_batch_100.png
# Epoch [3/200] Batch 150/1987                 Loss D: 0.0173, Loss G: 4.5147
# Saved image: generatedimages\epoch_3_batch_150.png
# Epoch [3/200] Batch 200/1987                 Loss D: 0.0017, Loss G: 8.0709
# Saved image: generatedimages\epoch_3_batch_200.png
# Epoch [3/200] Batch 250/1987                 Loss D: 0.2404, Loss G: 7.2716
# Saved image: generatedimages\epoch_3_batch_250.png
# Epoch [3/200] Batch 300/1987                 Loss D: 0.0009, Loss G: 9.4778
# Saved image: generatedimages\epoch_3_batch_300.png
# Epoch [3/200] Batch 350/1987                 Loss D: 0.0083, Loss G: 6.3348
# Saved image: generatedimages\epoch_3_batch_350.png
# Epoch [3/200] Batch 400/1987                 Loss D: 0.1325, Loss G: 6.3044
# Saved image: generatedimages\epoch_3_batch_400.png
# Epoch [3/200] Batch 450/1987                 Loss D: 0.0150, Loss G: 4.7923
# Saved image: generatedimages\epoch_3_batch_450.png
# Epoch [3/200] Batch 500/1987                 Loss D: 0.0605, Loss G: 4.9896
# Saved image: generatedimages\epoch_3_batch_500.png
# Epoch [3/200] Batch 550/1987                 Loss D: 0.0175, Loss G: 6.4345
# Saved image: generatedimages\epoch_3_batch_550.png
# Epoch [3/200] Batch 600/1987                 Loss D: 0.0592, Loss G: 5.3820
# Saved image: generatedimages\epoch_3_batch_600.png
# Epoch [3/200] Batch 650/1987                 Loss D: 0.0026, Loss G: 5.8760
# Saved image: generatedimages\epoch_3_batch_650.png
# Epoch [3/200] Batch 700/1987                 Loss D: 0.0117, Loss G: 6.8151
# Saved image: generatedimages\epoch_3_batch_700.png
# Epoch [3/200] Batch 750/1987                 Loss D: 0.0017, Loss G: 7.2164
# Saved image: generatedimages\epoch_3_batch_750.png
# Epoch [3/200] Batch 800/1987                 Loss D: 0.0925, Loss G: 8.5743
# Saved image: generatedimages\epoch_3_batch_800.png
# Epoch [3/200] Batch 850/1987                 Loss D: 0.0208, Loss G: 6.0112
# Saved image: generatedimages\epoch_3_batch_850.png
# Epoch [3/200] Batch 900/1987                 Loss D: 0.0030, Loss G: 9.4117
# Saved image: generatedimages\epoch_3_batch_900.png
# Epoch [3/200] Batch 950/1987                 Loss D: 0.0021, Loss G: 10.0797
# Saved image: generatedimages\epoch_3_batch_950.png
# Epoch [3/200] Batch 1000/1987                 Loss D: 0.0447, Loss G: 10.1812
# Saved image: generatedimages\epoch_3_batch_1000.png
# Epoch [3/200] Batch 1050/1987                 Loss D: 0.0042, Loss G: 6.6461
# Saved image: generatedimages\epoch_3_batch_1050.png
# Epoch [3/200] Batch 1100/1987                 Loss D: 0.2385, Loss G: 12.6702
# Saved image: generatedimages\epoch_3_batch_1100.png
# Epoch [3/200] Batch 1150/1987                 Loss D: 0.0664, Loss G: 13.4133
# Saved image: generatedimages\epoch_3_batch_1150.png
# Epoch [3/200] Batch 1200/1987                 Loss D: 0.0158, Loss G: 7.9959
# Saved image: generatedimages\epoch_3_batch_1200.png
# Epoch [3/200] Batch 1250/1987                 Loss D: 0.0781, Loss G: 8.3131
# Saved image: generatedimages\epoch_3_batch_1250.png
# Epoch [3/200] Batch 1300/1987                 Loss D: 0.0135, Loss G: 8.8434
# Saved image: generatedimages\epoch_3_batch_1300.png
# Epoch [3/200] Batch 1350/1987                 Loss D: 0.0399, Loss G: 9.1074
# Saved image: generatedimages\epoch_3_batch_1350.png
# Epoch [3/200] Batch 1400/1987                 Loss D: 0.0578, Loss G: 5.6531
# Saved image: generatedimages\epoch_3_batch_1400.png
# Epoch [3/200] Batch 1450/1987                 Loss D: 0.0903, Loss G: 5.1651
# Saved image: generatedimages\epoch_3_batch_1450.png
# Epoch [3/200] Batch 1500/1987                 Loss D: 0.0622, Loss G: 3.9239
# Saved image: generatedimages\epoch_3_batch_1500.png
# Epoch [3/200] Batch 1550/1987                 Loss D: 0.1002, Loss G: 5.3679
# Saved image: generatedimages\epoch_3_batch_1550.png
# Epoch [3/200] Batch 1600/1987                 Loss D: 0.0238, Loss G: 4.6631
# Saved image: generatedimages\epoch_3_batch_1600.png
# Epoch [3/200] Batch 1650/1987                 Loss D: 0.0152, Loss G: 4.9002
# Saved image: generatedimages\epoch_3_batch_1650.png
# Epoch [3/200] Batch 1700/1987                 Loss D: 0.1324, Loss G: 3.9474
# Saved image: generatedimages\epoch_3_batch_1700.png
# Epoch [3/200] Batch 1750/1987                 Loss D: 0.0021, Loss G: 7.2827
# Saved image: generatedimages\epoch_3_batch_1750.png
# Epoch [3/200] Batch 1800/1987                 Loss D: 0.0403, Loss G: 6.7106
# Saved image: generatedimages\epoch_3_batch_1800.png
# Epoch [3/200] Batch 1850/1987                 Loss D: 0.0232, Loss G: 4.2551
# Saved image: generatedimages\epoch_3_batch_1850.png
# Epoch [3/200] Batch 1900/1987                 Loss D: 0.1129, Loss G: 8.7807
# Saved image: generatedimages\epoch_3_batch_1900.png
# Epoch [3/200] Batch 1950/1987                 Loss D: 0.1605, Loss G: 4.6100
# Saved image: generatedimages\epoch_3_batch_1950.png
# Epoch [4/200] Batch 0/1987                 Loss D: 0.0001, Loss G: 10.2181
# Saved image: generatedimages\epoch_4_batch_0.png
# Epoch [4/200] Batch 50/1987                 Loss D: 0.1807, Loss G: 5.6133
# Saved image: generatedimages\epoch_4_batch_50.png
# Epoch [4/200] Batch 100/1987                 Loss D: 0.0107, Loss G: 5.3099
# Saved image: generatedimages\epoch_4_batch_100.png
# Epoch [4/200] Batch 150/1987                 Loss D: 0.0087, Loss G: 5.8999
# Saved image: generatedimages\epoch_4_batch_150.png
# Epoch [4/200] Batch 200/1987                 Loss D: 0.0507, Loss G: 3.3050
# Saved image: generatedimages\epoch_4_batch_200.png
# Epoch [4/200] Batch 250/1987                 Loss D: 0.0569, Loss G: 5.6277
# Saved image: generatedimages\epoch_4_batch_250.png
# Epoch [4/200] Batch 300/1987                 Loss D: 0.0024, Loss G: 7.6433
# Saved image: generatedimages\epoch_4_batch_300.png
# Epoch [4/200] Batch 350/1987                 Loss D: 0.0487, Loss G: 5.0754
# Saved image: generatedimages\epoch_4_batch_350.png
# Epoch [4/200] Batch 400/1987                 Loss D: 0.0096, Loss G: 6.5288
# Saved image: generatedimages\epoch_4_batch_400.png
# Epoch [4/200] Batch 450/1987                 Loss D: 0.0453, Loss G: 4.1228
# Saved image: generatedimages\epoch_4_batch_450.png
# Epoch [4/200] Batch 500/1987                 Loss D: 0.0300, Loss G: 4.9262
# Saved image: generatedimages\epoch_4_batch_500.png
# Epoch [4/200] Batch 550/1987                 Loss D: 0.0255, Loss G: 4.3497
# Saved image: generatedimages\epoch_4_batch_550.png
# Epoch [4/200] Batch 600/1987                 Loss D: 0.0027, Loss G: 8.6863
# Saved image: generatedimages\epoch_4_batch_600.png
# Epoch [4/200] Batch 650/1987                 Loss D: 0.0005, Loss G: 8.3680
# Saved image: generatedimages\epoch_4_batch_650.png
# Epoch [4/200] Batch 700/1987                 Loss D: 0.0126, Loss G: 5.7606
# Saved image: generatedimages\epoch_4_batch_700.png
# Epoch [4/200] Batch 750/1987                 Loss D: 0.1116, Loss G: 3.7916
# Saved image: generatedimages\epoch_4_batch_750.png
# Epoch [4/200] Batch 800/1987                 Loss D: 0.0056, Loss G: 5.3326
# Saved image: generatedimages\epoch_4_batch_800.png
# Epoch [4/200] Batch 850/1987                 Loss D: 0.0121, Loss G: 4.9747
# Saved image: generatedimages\epoch_4_batch_850.png
# Epoch [4/200] Batch 900/1987                 Loss D: 0.1229, Loss G: 4.6253
# Saved image: generatedimages\epoch_4_batch_900.png
# Epoch [4/200] Batch 950/1987                 Loss D: 0.0345, Loss G: 6.3254
# Saved image: generatedimages\epoch_4_batch_950.png
# Epoch [4/200] Batch 1000/1987                 Loss D: 0.0866, Loss G: 5.1871
# Saved image: generatedimages\epoch_4_batch_1000.png
# Epoch [4/200] Batch 1050/1987                 Loss D: 0.0045, Loss G: 6.4177
# Saved image: generatedimages\epoch_4_batch_1050.png
# Epoch [4/200] Batch 1100/1987                 Loss D: 0.0512, Loss G: 5.1750
# Saved image: generatedimages\epoch_4_batch_1100.png
# Epoch [4/200] Batch 1150/1987                 Loss D: 0.0023, Loss G: 6.7325
# Saved image: generatedimages\epoch_4_batch_1150.png
# Epoch [4/200] Batch 1200/1987                 Loss D: 0.0175, Loss G: 5.0780
# Saved image: generatedimages\epoch_4_batch_1200.png
# Epoch [4/200] Batch 1250/1987                 Loss D: 0.0278, Loss G: 4.3742
# Saved image: generatedimages\epoch_4_batch_1250.png
# Epoch [4/200] Batch 1300/1987                 Loss D: 0.0426, Loss G: 4.0255
# Saved image: generatedimages\epoch_4_batch_1300.png
# Epoch [4/200] Batch 1350/1987                 Loss D: 0.0214, Loss G: 5.5381
# Saved image: generatedimages\epoch_4_batch_1350.png
# Epoch [4/200] Batch 1400/1987                 Loss D: 0.0771, Loss G: 3.6782
# Saved image: generatedimages\epoch_4_batch_1400.png
# Epoch [4/200] Batch 1450/1987                 Loss D: 0.0388, Loss G: 5.6832
# Saved image: generatedimages\epoch_4_batch_1450.png
# Epoch [4/200] Batch 1500/1987                 Loss D: 0.0693, Loss G: 6.0956
# Saved image: generatedimages\epoch_4_batch_1500.png
# Epoch [4/200] Batch 1550/1987                 Loss D: 0.1158, Loss G: 5.9674
# Saved image: generatedimages\epoch_4_batch_1550.png
# Epoch [4/200] Batch 1600/1987                 Loss D: 0.1474, Loss G: 4.6457
# Saved image: generatedimages\epoch_4_batch_1600.png
# Epoch [4/200] Batch 1650/1987                 Loss D: 0.0570, Loss G: 4.1274
# Saved image: generatedimages\epoch_4_batch_1650.png
# Epoch [4/200] Batch 1700/1987                 Loss D: 0.0872, Loss G: 5.6356
# Saved image: generatedimages\epoch_4_batch_1700.png
# Epoch [4/200] Batch 1750/1987                 Loss D: 0.0406, Loss G: 3.6093
# Saved image: generatedimages\epoch_4_batch_1750.png
# Epoch [4/200] Batch 1800/1987                 Loss D: 0.1540, Loss G: 6.1764
# Saved image: generatedimages\epoch_4_batch_1800.png
# Epoch [4/200] Batch 1850/1987                 Loss D: 0.0086, Loss G: 5.9326
# Saved image: generatedimages\epoch_4_batch_1850.png
# Epoch [4/200] Batch 1900/1987                 Loss D: 0.0390, Loss G: 4.0233
# Saved image: generatedimages\epoch_4_batch_1900.png
# Epoch [4/200] Batch 1950/1987                 Loss D: 0.0695, Loss G: 4.8834
# Saved image: generatedimages\epoch_4_batch_1950.png
# Epoch [5/200] Batch 0/1987                 Loss D: 0.0033, Loss G: 6.2345
# Saved image: generatedimages\epoch_5_batch_0.png
# Epoch [5/200] Batch 50/1987                 Loss D: 0.0059, Loss G: 6.3501
# Saved image: generatedimages\epoch_5_batch_50.png
# Epoch [5/200] Batch 100/1987                 Loss D: 0.0398, Loss G: 4.0352
# Saved image: generatedimages\epoch_5_batch_100.png
# Epoch [5/200] Batch 150/1987                 Loss D: 0.0049, Loss G: 6.6552
# Saved image: generatedimages\epoch_5_batch_150.png
# Epoch [5/200] Batch 200/1987                 Loss D: 0.0142, Loss G: 5.5079
# Saved image: generatedimages\epoch_5_batch_200.png
# Epoch [5/200] Batch 250/1987                 Loss D: 0.2354, Loss G: 4.3005
# Saved image: generatedimages\epoch_5_batch_250.png
# Epoch [5/200] Batch 300/1987                 Loss D: 0.0072, Loss G: 6.4077
# Saved image: generatedimages\epoch_5_batch_300.png
# Epoch [5/200] Batch 350/1987                 Loss D: 0.0532, Loss G: 7.4105
# Saved image: generatedimages\epoch_5_batch_350.png
# Epoch [5/200] Batch 400/1987                 Loss D: 0.1904, Loss G: 3.9860
# Saved image: generatedimages\epoch_5_batch_400.png
# Epoch [5/200] Batch 450/1987                 Loss D: 0.0630, Loss G: 3.4824
# Saved image: generatedimages\epoch_5_batch_450.png
# Epoch [5/200] Batch 500/1987                 Loss D: 0.1020, Loss G: 5.0565
# Saved image: generatedimages\epoch_5_batch_500.png
# Epoch [5/200] Batch 550/1987                 Loss D: 0.0879, Loss G: 4.2085
# Saved image: generatedimages\epoch_5_batch_550.png
# Epoch [5/200] Batch 600/1987                 Loss D: 0.0693, Loss G: 4.2661
# Saved image: generatedimages\epoch_5_batch_600.png
# Epoch [5/200] Batch 650/1987                 Loss D: 0.1156, Loss G: 4.3632
# Saved image: generatedimages\epoch_5_batch_650.png
# Epoch [5/200] Batch 700/1987                 Loss D: 0.0458, Loss G: 4.4097
# Saved image: generatedimages\epoch_5_batch_700.png
# Epoch [5/200] Batch 750/1987                 Loss D: 0.0723, Loss G: 5.8603
# Saved image: generatedimages\epoch_5_batch_750.png
# Epoch [5/200] Batch 800/1987                 Loss D: 0.0866, Loss G: 7.3733
# Saved image: generatedimages\epoch_5_batch_800.png
# Epoch [5/200] Batch 850/1987                 Loss D: 0.1349, Loss G: 6.0327
# Saved image: generatedimages\epoch_5_batch_850.png
# Epoch [5/200] Batch 900/1987                 Loss D: 0.0901, Loss G: 5.5294
# Saved image: generatedimages\epoch_5_batch_900.png
# Epoch [5/200] Batch 950/1987                 Loss D: 0.1530, Loss G: 6.0845
# Saved image: generatedimages\epoch_5_batch_950.png
# Epoch [5/200] Batch 1000/1987                 Loss D: 0.0210, Loss G: 5.2592
# Saved image: generatedimages\epoch_5_batch_1000.png
# Epoch [5/200] Batch 1050/1987                 Loss D: 0.0251, Loss G: 6.6157
# Saved image: generatedimages\epoch_5_batch_1050.png
# Epoch [5/200] Batch 1100/1987                 Loss D: 0.0448, Loss G: 4.8403
# Saved image: generatedimages\epoch_5_batch_1100.png
# Epoch [5/200] Batch 1150/1987                 Loss D: 0.0621, Loss G: 3.1296
# Saved image: generatedimages\epoch_5_batch_1150.png
# Epoch [5/200] Batch 1200/1987                 Loss D: 0.0973, Loss G: 6.2784
# Saved image: generatedimages\epoch_5_batch_1200.png
# Epoch [5/200] Batch 1250/1987                 Loss D: 0.0369, Loss G: 4.5599
# Saved image: generatedimages\epoch_5_batch_1250.png
# Epoch [5/200] Batch 1300/1987                 Loss D: 0.0444, Loss G: 4.1069
# Saved image: generatedimages\epoch_5_batch_1300.png
# Epoch [5/200] Batch 1350/1987                 Loss D: 0.0165, Loss G: 6.0238
# Saved image: generatedimages\epoch_5_batch_1350.png
# Epoch [5/200] Batch 1400/1987                 Loss D: 0.0751, Loss G: 5.5442
# Saved image: generatedimages\epoch_5_batch_1400.png
# Epoch [5/200] Batch 1450/1987                 Loss D: 0.1714, Loss G: 4.4376
# Saved image: generatedimages\epoch_5_batch_1450.png
# Epoch [5/200] Batch 1500/1987                 Loss D: 0.0881, Loss G: 3.9927
# Saved image: generatedimages\epoch_5_batch_1500.png
# Epoch [5/200] Batch 1550/1987                 Loss D: 0.2561, Loss G: 6.7051
# Saved image: generatedimages\epoch_5_batch_1550.png
# Epoch [5/200] Batch 1600/1987                 Loss D: 0.0449, Loss G: 6.5210
# Saved image: generatedimages\epoch_5_batch_1600.png
# Epoch [5/200] Batch 1650/1987                 Loss D: 0.0516, Loss G: 3.4719
# Saved image: generatedimages\epoch_5_batch_1650.png
# Epoch [5/200] Batch 1700/1987                 Loss D: 0.1721, Loss G: 6.1835
# Saved image: generatedimages\epoch_5_batch_1700.png
# Epoch [5/200] Batch 1750/1987                 Loss D: 0.0457, Loss G: 6.9098
# Saved image: generatedimages\epoch_5_batch_1750.png
# Epoch [5/200] Batch 1800/1987                 Loss D: 0.1369, Loss G: 5.3075
# Saved image: generatedimages\epoch_5_batch_1800.png
# Epoch [5/200] Batch 1850/1987                 Loss D: 0.0293, Loss G: 3.9675
# Saved image: generatedimages\epoch_5_batch_1850.png
# Epoch [5/200] Batch 1900/1987                 Loss D: 0.1093, Loss G: 7.9856
# Saved image: generatedimages\epoch_5_batch_1900.png
# Epoch [5/200] Batch 1950/1987                 Loss D: 0.1180, Loss G: 5.2094
# Saved image: generatedimages\epoch_5_batch_1950.png
# Epoch [6/200] Batch 0/1987                 Loss D: 0.0950, Loss G: 6.9963
# Saved image: generatedimages\epoch_6_batch_0.png
# Epoch [6/200] Batch 50/1987                 Loss D: 0.0601, Loss G: 5.4634
# Saved image: generatedimages\epoch_6_batch_50.png
# Epoch [6/200] Batch 100/1987                 Loss D: 0.2435, Loss G: 4.5967
# Saved image: generatedimages\epoch_6_batch_100.png
# Epoch [6/200] Batch 150/1987                 Loss D: 0.0713, Loss G: 4.3595
# Saved image: generatedimages\epoch_6_batch_150.png
# Epoch [6/200] Batch 200/1987                 Loss D: 0.1476, Loss G: 5.0812
# Saved image: generatedimages\epoch_6_batch_200.png
# Epoch [6/200] Batch 250/1987                 Loss D: 0.1835, Loss G: 6.3570
# Saved image: generatedimages\epoch_6_batch_250.png
# Epoch [6/200] Batch 300/1987                 Loss D: 0.0559, Loss G: 4.0666
# Saved image: generatedimages\epoch_6_batch_300.png
# Epoch [6/200] Batch 350/1987                 Loss D: 0.0484, Loss G: 6.0066
# Saved image: generatedimages\epoch_6_batch_350.png
# Epoch [6/200] Batch 400/1987                 Loss D: 0.0857, Loss G: 6.4843
# Saved image: generatedimages\epoch_6_batch_400.png
# Epoch [6/200] Batch 450/1987                 Loss D: 0.1364, Loss G: 4.5614
# Saved image: generatedimages\epoch_6_batch_450.png
# Epoch [6/200] Batch 500/1987                 Loss D: 0.0610, Loss G: 4.5488
# Saved image: generatedimages\epoch_6_batch_500.png
# Epoch [6/200] Batch 550/1987                 Loss D: 0.0273, Loss G: 5.1868
# Saved image: generatedimages\epoch_6_batch_550.png
# Epoch [6/200] Batch 600/1987                 Loss D: 0.0448, Loss G: 4.7221
# Saved image: generatedimages\epoch_6_batch_600.png
# Epoch [6/200] Batch 650/1987                 Loss D: 0.3467, Loss G: 5.1616
# Saved image: generatedimages\epoch_6_batch_650.png
# Epoch [6/200] Batch 700/1987                 Loss D: 0.0191, Loss G: 5.0753
# Saved image: generatedimages\epoch_6_batch_700.png
# Epoch [6/200] Batch 750/1987                 Loss D: 0.1061, Loss G: 4.1284
# Saved image: generatedimages\epoch_6_batch_750.png
# Epoch [6/200] Batch 800/1987                 Loss D: 0.0653, Loss G: 6.4542
# Saved image: generatedimages\epoch_6_batch_800.png
# Epoch [6/200] Batch 850/1987                 Loss D: 0.1139, Loss G: 5.3760
# Saved image: generatedimages\epoch_6_batch_850.png
# Epoch [6/200] Batch 900/1987                 Loss D: 0.1358, Loss G: 3.5930
# Saved image: generatedimages\epoch_6_batch_900.png
# Epoch [6/200] Batch 950/1987                 Loss D: 0.1406, Loss G: 6.3722
# Saved image: generatedimages\epoch_6_batch_950.png
# Epoch [6/200] Batch 1000/1987                 Loss D: 0.0456, Loss G: 4.5557
# Saved image: generatedimages\epoch_6_batch_1000.png
# Epoch [6/200] Batch 1050/1987                 Loss D: 0.0460, Loss G: 6.2567
# Saved image: generatedimages\epoch_6_batch_1050.png
# Epoch [6/200] Batch 1100/1987                 Loss D: 0.0359, Loss G: 4.3395
# Saved image: generatedimages\epoch_6_batch_1100.png
# Epoch [6/200] Batch 1150/1987                 Loss D: 0.0451, Loss G: 3.6443
# Saved image: generatedimages\epoch_6_batch_1150.png
# Epoch [6/200] Batch 1200/1987                 Loss D: 0.2020, Loss G: 7.9366
# Saved image: generatedimages\epoch_6_batch_1200.png
# Epoch [6/200] Batch 1250/1987                 Loss D: 0.2960, Loss G: 5.0448
# Saved image: generatedimages\epoch_6_batch_1250.png
# Epoch [6/200] Batch 1300/1987                 Loss D: 0.0810, Loss G: 7.1092
# Saved image: generatedimages\epoch_6_batch_1300.png
# Epoch [6/200] Batch 1350/1987                 Loss D: 0.1363, Loss G: 5.3448
# Saved image: generatedimages\epoch_6_batch_1350.png
# Epoch [6/200] Batch 1400/1987                 Loss D: 0.0380, Loss G: 5.8525
# Saved image: generatedimages\epoch_6_batch_1400.png
# Epoch [6/200] Batch 1450/1987                 Loss D: 0.1275, Loss G: 5.9165
# Saved image: generatedimages\epoch_6_batch_1450.png
# Epoch [6/200] Batch 1500/1987                 Loss D: 0.1902, Loss G: 6.5348
# Saved image: generatedimages\epoch_6_batch_1500.png
# Epoch [6/200] Batch 1550/1987                 Loss D: 0.2620, Loss G: 3.0119
# Saved image: generatedimages\epoch_6_batch_1550.png
# Epoch [6/200] Batch 1600/1987                 Loss D: 0.0274, Loss G: 6.1954
# Saved image: generatedimages\epoch_6_batch_1600.png
# Epoch [6/200] Batch 1650/1987                 Loss D: 0.0736, Loss G: 7.2621
# Saved image: generatedimages\epoch_6_batch_1650.png
# Epoch [6/200] Batch 1700/1987                 Loss D: 0.0895, Loss G: 6.1045
# Saved image: generatedimages\epoch_6_batch_1700.png
# Epoch [6/200] Batch 1750/1987                 Loss D: 0.0514, Loss G: 4.8025
# Saved image: generatedimages\epoch_6_batch_1750.png
# Epoch [6/200] Batch 1800/1987                 Loss D: 0.0351, Loss G: 5.1844
# Saved image: generatedimages\epoch_6_batch_1800.png
# Epoch [6/200] Batch 1850/1987                 Loss D: 0.1450, Loss G: 4.1952
# Saved image: generatedimages\epoch_6_batch_1850.png
# Epoch [6/200] Batch 1900/1987                 Loss D: 0.0406, Loss G: 5.6281
# Saved image: generatedimages\epoch_6_batch_1900.png
# Epoch [6/200] Batch 1950/1987                 Loss D: 0.1592, Loss G: 5.4173
# Saved image: generatedimages\epoch_6_batch_1950.png
# Epoch [7/200] Batch 0/1987                 Loss D: 0.0624, Loss G: 4.0463
# Saved image: generatedimages\epoch_7_batch_0.png
# Epoch [7/200] Batch 50/1987                 Loss D: 0.1082, Loss G: 5.2679
# Saved image: generatedimages\epoch_7_batch_50.png
# Epoch [7/200] Batch 100/1987                 Loss D: 0.0379, Loss G: 3.8616
# Saved image: generatedimages\epoch_7_batch_100.png
# Epoch [7/200] Batch 150/1987                 Loss D: 0.0958, Loss G: 4.0071
# Saved image: generatedimages\epoch_7_batch_150.png
# Epoch [7/200] Batch 200/1987                 Loss D: 0.0244, Loss G: 5.2052
# Saved image: generatedimages\epoch_7_batch_200.png
# Epoch [7/200] Batch 250/1987                 Loss D: 0.0646, Loss G: 5.0345
# Saved image: generatedimages\epoch_7_batch_250.png
# Epoch [7/200] Batch 300/1987                 Loss D: 0.0517, Loss G: 5.1283
# Saved image: generatedimages\epoch_7_batch_300.png
# Epoch [7/200] Batch 350/1987                 Loss D: 0.1123, Loss G: 4.2268
# Saved image: generatedimages\epoch_7_batch_350.png
# Epoch [7/200] Batch 400/1987                 Loss D: 0.0756, Loss G: 5.4610
# Saved image: generatedimages\epoch_7_batch_400.png
# Epoch [7/200] Batch 450/1987                 Loss D: 0.1514, Loss G: 5.4792
# Saved image: generatedimages\epoch_7_batch_450.png
# Epoch [7/200] Batch 500/1987                 Loss D: 0.0589, Loss G: 4.4316
# Saved image: generatedimages\epoch_7_batch_500.png
# Epoch [7/200] Batch 550/1987                 Loss D: 0.1510, Loss G: 4.0787
# Saved image: generatedimages\epoch_7_batch_550.png
# Epoch [7/200] Batch 600/1987                 Loss D: 0.0730, Loss G: 4.4839
# Saved image: generatedimages\epoch_7_batch_600.png
# Epoch [7/200] Batch 650/1987                 Loss D: 0.0875, Loss G: 3.6301
# Saved image: generatedimages\epoch_7_batch_650.png
# Epoch [7/200] Batch 700/1987                 Loss D: 0.0642, Loss G: 3.7667
# Saved image: generatedimages\epoch_7_batch_700.png
# Epoch [7/200] Batch 750/1987                 Loss D: 0.0615, Loss G: 4.4938
# Saved image: generatedimages\epoch_7_batch_750.png
# Epoch [7/200] Batch 800/1987                 Loss D: 0.0892, Loss G: 3.9131
# Saved image: generatedimages\epoch_7_batch_800.png
# Epoch [7/200] Batch 850/1987                 Loss D: 0.0808, Loss G: 4.5156
# Saved image: generatedimages\epoch_7_batch_850.png
# Epoch [7/200] Batch 900/1987                 Loss D: 0.0760, Loss G: 7.1909
# Saved image: generatedimages\epoch_7_batch_900.png
# Epoch [7/200] Batch 950/1987                 Loss D: 0.1254, Loss G: 4.7052
# Saved image: generatedimages\epoch_7_batch_950.png
# Epoch [7/200] Batch 1000/1987                 Loss D: 0.0493, Loss G: 4.5051
# Saved image: generatedimages\epoch_7_batch_1000.png
# Epoch [7/200] Batch 1050/1987                 Loss D: 0.1888, Loss G: 5.5219
# Saved image: generatedimages\epoch_7_batch_1050.png
# Epoch [7/200] Batch 1100/1987                 Loss D: 0.0907, Loss G: 6.3977
# Saved image: generatedimages\epoch_7_batch_1100.png
# Epoch [7/200] Batch 1150/1987                 Loss D: 0.0969, Loss G: 4.0909
# Saved image: generatedimages\epoch_7_batch_1150.png
# Epoch [7/200] Batch 1200/1987                 Loss D: 0.0393, Loss G: 5.5155
# Saved image: generatedimages\epoch_7_batch_1200.png
# Epoch [7/200] Batch 1250/1987                 Loss D: 0.1131, Loss G: 5.5048
# Saved image: generatedimages\epoch_7_batch_1250.png
# Epoch [7/200] Batch 1300/1987                 Loss D: 0.0897, Loss G: 3.5444
# Saved image: generatedimages\epoch_7_batch_1300.png
# Epoch [7/200] Batch 1350/1987                 Loss D: 0.0798, Loss G: 7.9710
# Saved image: generatedimages\epoch_7_batch_1350.png
# Epoch [7/200] Batch 1400/1987                 Loss D: 0.0341, Loss G: 5.3361
# Saved image: generatedimages\epoch_7_batch_1400.png
# Epoch [7/200] Batch 1450/1987                 Loss D: 0.1735, Loss G: 4.8042
# Saved image: generatedimages\epoch_7_batch_1450.png
# Epoch [7/200] Batch 1500/1987                 Loss D: 0.0251, Loss G: 5.7348
# Saved image: generatedimages\epoch_7_batch_1500.png
# Epoch [7/200] Batch 1550/1987                 Loss D: 0.0846, Loss G: 3.9401
# Saved image: generatedimages\epoch_7_batch_1550.png
# Epoch [7/200] Batch 1600/1987                 Loss D: 0.1429, Loss G: 5.7004
# Saved image: generatedimages\epoch_7_batch_1600.png
# Epoch [7/200] Batch 1650/1987                 Loss D: 0.0818, Loss G: 6.9115
# Saved image: generatedimages\epoch_7_batch_1650.png
# Epoch [7/200] Batch 1700/1987                 Loss D: 0.1108, Loss G: 5.9594
# Saved image: generatedimages\epoch_7_batch_1700.png
# Epoch [7/200] Batch 1750/1987                 Loss D: 0.1246, Loss G: 4.4842
# Saved image: generatedimages\epoch_7_batch_1750.png
# Epoch [7/200] Batch 1800/1987                 Loss D: 0.1443, Loss G: 6.5203
# Saved image: generatedimages\epoch_7_batch_1800.png
# Epoch [7/200] Batch 1850/1987                 Loss D: 0.0358, Loss G: 5.7426
# Saved image: generatedimages\epoch_7_batch_1850.png
# Epoch [7/200] Batch 1900/1987                 Loss D: 0.0886, Loss G: 4.7341
# Saved image: generatedimages\epoch_7_batch_1900.png
# Epoch [7/200] Batch 1950/1987                 Loss D: 0.1126, Loss G: 3.6715
# Saved image: generatedimages\epoch_7_batch_1950.png
# Epoch [8/200] Batch 0/1987                 Loss D: 0.0577, Loss G: 7.7228
# Saved image: generatedimages\epoch_8_batch_0.png
# Epoch [8/200] Batch 50/1987                 Loss D: 0.0530, Loss G: 5.7464
# Saved image: generatedimages\epoch_8_batch_50.png
# Epoch [8/200] Batch 100/1987                 Loss D: 0.0891, Loss G: 5.7199
# Saved image: generatedimages\epoch_8_batch_100.png
# Epoch [8/200] Batch 150/1987                 Loss D: 0.0771, Loss G: 5.0203
# Saved image: generatedimages\epoch_8_batch_150.png
# Epoch [8/200] Batch 200/1987                 Loss D: 0.0709, Loss G: 5.0208
# Saved image: generatedimages\epoch_8_batch_200.png
# Epoch [8/200] Batch 250/1987                 Loss D: 0.1066, Loss G: 4.1277
# Saved image: generatedimages\epoch_8_batch_250.png
# Epoch [8/200] Batch 300/1987                 Loss D: 0.1094, Loss G: 4.3539
# Saved image: generatedimages\epoch_8_batch_300.png
# Epoch [8/200] Batch 350/1987                 Loss D: 0.0339, Loss G: 4.8669
# Saved image: generatedimages\epoch_8_batch_350.png
# Epoch [8/200] Batch 400/1987                 Loss D: 0.1622, Loss G: 4.6378
# Saved image: generatedimages\epoch_8_batch_400.png
# Epoch [8/200] Batch 450/1987                 Loss D: 0.1533, Loss G: 4.2717
# Saved image: generatedimages\epoch_8_batch_450.png
# Epoch [8/200] Batch 500/1987                 Loss D: 0.1795, Loss G: 4.8257
# Saved image: generatedimages\epoch_8_batch_500.png
# Epoch [8/200] Batch 550/1987                 Loss D: 0.0300, Loss G: 4.1714
# Saved image: generatedimages\epoch_8_batch_550.png
# Epoch [8/200] Batch 600/1987                 Loss D: 0.0360, Loss G: 5.8490
# Saved image: generatedimages\epoch_8_batch_600.png
# Epoch [8/200] Batch 650/1987                 Loss D: 0.0993, Loss G: 5.0256
# Saved image: generatedimages\epoch_8_batch_650.png
# Epoch [8/200] Batch 700/1987                 Loss D: 0.1239, Loss G: 5.9998
# Saved image: generatedimages\epoch_8_batch_700.png
# Epoch [8/200] Batch 750/1987                 Loss D: 0.2863, Loss G: 4.0820
# Saved image: generatedimages\epoch_8_batch_750.png
# Epoch [8/200] Batch 800/1987                 Loss D: 0.0742, Loss G: 4.6466
# Saved image: generatedimages\epoch_8_batch_800.png
# Epoch [8/200] Batch 850/1987                 Loss D: 0.1611, Loss G: 4.0424
# Saved image: generatedimages\epoch_8_batch_850.png
# Epoch [8/200] Batch 900/1987                 Loss D: 0.0681, Loss G: 4.1695
# Saved image: generatedimages\epoch_8_batch_900.png
# Epoch [8/200] Batch 950/1987                 Loss D: 0.1041, Loss G: 7.7925
# Saved image: generatedimages\epoch_8_batch_950.png
# Epoch [8/200] Batch 1000/1987                 Loss D: 0.2469, Loss G: 7.7363
# Saved image: generatedimages\epoch_8_batch_1000.png
# Epoch [8/200] Batch 1050/1987                 Loss D: 0.0912, Loss G: 4.3454
# Saved image: generatedimages\epoch_8_batch_1050.png
# Epoch [8/200] Batch 1100/1987                 Loss D: 0.1585, Loss G: 5.9659
# Saved image: generatedimages\epoch_8_batch_1100.png
# Epoch [8/200] Batch 1150/1987                 Loss D: 0.0806, Loss G: 4.9286
# Saved image: generatedimages\epoch_8_batch_1150.png
# Epoch [8/200] Batch 1200/1987                 Loss D: 0.1624, Loss G: 4.3452
# Saved image: generatedimages\epoch_8_batch_1200.png
# Epoch [8/200] Batch 1250/1987                 Loss D: 0.0964, Loss G: 4.5366
# Saved image: generatedimages\epoch_8_batch_1250.png
# Epoch [8/200] Batch 1300/1987                 Loss D: 0.1732, Loss G: 3.9219
# Saved image: generatedimages\epoch_8_batch_1300.png
# Epoch [8/200] Batch 1350/1987                 Loss D: 0.1189, Loss G: 3.5858
# Saved image: generatedimages\epoch_8_batch_1350.png
# Epoch [8/200] Batch 1400/1987                 Loss D: 0.0879, Loss G: 4.4735
# Saved image: generatedimages\epoch_8_batch_1400.png
# Epoch [8/200] Batch 1450/1987                 Loss D: 0.3342, Loss G: 7.7051
# Saved image: generatedimages\epoch_8_batch_1450.png
# Epoch [8/200] Batch 1500/1987                 Loss D: 0.0438, Loss G: 4.6221
# Saved image: generatedimages\epoch_8_batch_1500.png
# Epoch [8/200] Batch 1550/1987                 Loss D: 0.0699, Loss G: 5.2984
# Saved image: generatedimages\epoch_8_batch_1550.png
# Epoch [8/200] Batch 1600/1987                 Loss D: 0.3303, Loss G: 3.7689
# Saved image: generatedimages\epoch_8_batch_1600.png
# Epoch [8/200] Batch 1650/1987                 Loss D: 0.0482, Loss G: 6.0906
# Saved image: generatedimages\epoch_8_batch_1650.png
# Epoch [8/200] Batch 1700/1987                 Loss D: 0.1652, Loss G: 5.3646
# Saved image: generatedimages\epoch_8_batch_1700.png
# Epoch [8/200] Batch 1750/1987                 Loss D: 0.0575, Loss G: 5.0367
# Saved image: generatedimages\epoch_8_batch_1750.png
# Epoch [8/200] Batch 1800/1987                 Loss D: 0.0484, Loss G: 4.6737
# Saved image: generatedimages\epoch_8_batch_1800.png
# Epoch [8/200] Batch 1850/1987                 Loss D: 0.1077, Loss G: 5.5078
# Saved image: generatedimages\epoch_8_batch_1850.png
# Epoch [8/200] Batch 1900/1987                 Loss D: 0.1052, Loss G: 5.3661
# Saved image: generatedimages\epoch_8_batch_1900.png
# Epoch [8/200] Batch 1950/1987                 Loss D: 0.0838, Loss G: 3.6904
# Saved image: generatedimages\epoch_8_batch_1950.png
# Epoch [9/200] Batch 0/1987                 Loss D: 0.0848, Loss G: 4.5744
# Saved image: generatedimages\epoch_9_batch_0.png
# Epoch [9/200] Batch 50/1987                 Loss D: 0.0462, Loss G: 5.1910
# Saved image: generatedimages\epoch_9_batch_50.png
# Epoch [9/200] Batch 100/1987                 Loss D: 0.1542, Loss G: 3.8368
# Saved image: generatedimages\epoch_9_batch_100.png
# Epoch [9/200] Batch 150/1987                 Loss D: 0.0572, Loss G: 4.8579
# Saved image: generatedimages\epoch_9_batch_150.png
# Epoch [9/200] Batch 200/1987                 Loss D: 0.0323, Loss G: 4.7766
# Saved image: generatedimages\epoch_9_batch_200.png
# Epoch [9/200] Batch 250/1987                 Loss D: 0.0982, Loss G: 4.8841
# Saved image: generatedimages\epoch_9_batch_250.png
# Epoch [9/200] Batch 300/1987                 Loss D: 0.0485, Loss G: 4.0268
# Saved image: generatedimages\epoch_9_batch_300.png
# Epoch [9/200] Batch 350/1987                 Loss D: 0.1536, Loss G: 3.7237
# Saved image: generatedimages\epoch_9_batch_350.png
# Epoch [9/200] Batch 400/1987                 Loss D: 0.1305, Loss G: 6.4861
# Saved image: generatedimages\epoch_9_batch_400.png
# Epoch [9/200] Batch 450/1987                 Loss D: 0.1344, Loss G: 3.9372
# Saved image: generatedimages\epoch_9_batch_450.png
# Epoch [9/200] Batch 500/1987                 Loss D: 0.0818, Loss G: 3.4441
# Saved image: generatedimages\epoch_9_batch_500.png
# Epoch [9/200] Batch 550/1987                 Loss D: 0.0609, Loss G: 4.4606
# Saved image: generatedimages\epoch_9_batch_550.png
# Epoch [9/200] Batch 600/1987                 Loss D: 0.1837, Loss G: 8.9132
# Saved image: generatedimages\epoch_9_batch_600.png
# Epoch [9/200] Batch 650/1987                 Loss D: 0.1727, Loss G: 5.3509
# Saved image: generatedimages\epoch_9_batch_650.png
# Epoch [9/200] Batch 700/1987                 Loss D: 0.0305, Loss G: 5.5044
# Saved image: generatedimages\epoch_9_batch_700.png
# ...
# Saved image: generatedimages\epoch_182_batch_1100.png
# Epoch [182/200] Batch 1150/1987                 Loss D: 0.4581, Loss G: 1.6351
# Saved image: generatedimages\epoch_182_batch_1150.png
# Epoch [182/200] Batch 1200/1987                 Loss D: 0.8193, Loss G: 1.3118
# Saved image: generatedimages\epoch_182_batch_1200.png
# Epoch [182/200] Batch 1250/1987                 Loss D: 0.4349, Loss G: 2.0066
# Saved image: generatedimages\epoch_182_batch_1250.png
# Epoch [182/200] Batch 1300/1987                 Loss D: 0.4830, Loss G: 1.5607
# Saved image: generatedimages\epoch_182_batch_1300.png
# Epoch [182/200] Batch 1350/1987                 Loss D: 0.4260, Loss G: 2.0635
# Saved image: generatedimages\epoch_182_batch_1350.png
# Epoch [182/200] Batch 1400/1987                 Loss D: 0.3658, Loss G: 2.0596
# Saved image: generatedimages\epoch_182_batch_1400.png
# Epoch [182/200] Batch 1450/1987                 Loss D: 0.5507, Loss G: 1.3904
# Saved image: generatedimages\epoch_182_batch_1450.png
# Epoch [182/200] Batch 1500/1987                 Loss D: 0.3986, Loss G: 2.1646
# Saved image: generatedimages\epoch_182_batch_1500.png
# Epoch [182/200] Batch 1550/1987                 Loss D: 0.4051, Loss G: 2.0874
# Saved image: generatedimages\epoch_182_batch_1550.png
# Epoch [182/200] Batch 1600/1987                 Loss D: 0.4047, Loss G: 2.2211
# Saved image: generatedimages\epoch_182_batch_1600.png
# Epoch [182/200] Batch 1650/1987                 Loss D: 0.3456, Loss G: 1.8692
# Saved image: generatedimages\epoch_182_batch_1650.png
# Epoch [182/200] Batch 1700/1987                 Loss D: 0.4809, Loss G: 2.0756
# Saved image: generatedimages\epoch_182_batch_1700.png
# Epoch [182/200] Batch 1750/1987                 Loss D: 0.4994, Loss G: 1.6359
# Saved image: generatedimages\epoch_182_batch_1750.png
# Epoch [182/200] Batch 1800/1987                 Loss D: 0.3908, Loss G: 1.7872
# Saved image: generatedimages\epoch_182_batch_1800.png
# Epoch [182/200] Batch 1850/1987                 Loss D: 0.4137, Loss G: 2.7877
# Saved image: generatedimages\epoch_182_batch_1850.png
# Epoch [182/200] Batch 1900/1987                 Loss D: 0.4451, Loss G: 1.6752
# Saved image: generatedimages\epoch_182_batch_1900.png
# Epoch [182/200] Batch 1950/1987                 Loss D: 0.4396, Loss G: 1.8199
# Saved image: generatedimages\epoch_182_batch_1950.png
# Epoch [183/200] Batch 0/1987                 Loss D: 0.4448, Loss G: 1.6962
# Saved image: generatedimages\epoch_183_batch_0.png
# Epoch [183/200] Batch 50/1987                 Loss D: 0.4296, Loss G: 1.9443
# Saved image: generatedimages\epoch_183_batch_50.png
# Epoch [183/200] Batch 100/1987                 Loss D: 0.4598, Loss G: 1.3384
# Saved image: generatedimages\epoch_183_batch_100.png
# Epoch [183/200] Batch 150/1987                 Loss D: 0.5523, Loss G: 2.1647
# Saved image: generatedimages\epoch_183_batch_150.png
# Epoch [183/200] Batch 200/1987                 Loss D: 0.4119, Loss G: 1.7774
# Saved image: generatedimages\epoch_183_batch_200.png
# Epoch [183/200] Batch 250/1987                 Loss D: 0.3764, Loss G: 1.5637
# Saved image: generatedimages\epoch_183_batch_250.png
# Epoch [183/200] Batch 300/1987                 Loss D: 0.4500, Loss G: 2.2387
# Saved image: generatedimages\epoch_183_batch_300.png
# Epoch [183/200] Batch 350/1987                 Loss D: 0.5108, Loss G: 1.6841
# Saved image: generatedimages\epoch_183_batch_350.png
# Epoch [183/200] Batch 400/1987                 Loss D: 0.5393, Loss G: 1.6230
# Saved image: generatedimages\epoch_183_batch_400.png
# Epoch [183/200] Batch 450/1987                 Loss D: 0.5441, Loss G: 1.7961
# Saved image: generatedimages\epoch_183_batch_450.png
# Epoch [183/200] Batch 500/1987                 Loss D: 0.5155, Loss G: 1.9232
# Saved image: generatedimages\epoch_183_batch_500.png
# Epoch [183/200] Batch 550/1987                 Loss D: 0.4360, Loss G: 2.0812
# Saved image: generatedimages\epoch_183_batch_550.png
# Epoch [183/200] Batch 600/1987                 Loss D: 0.4090, Loss G: 1.8315
# Saved image: generatedimages\epoch_183_batch_600.png
# Epoch [183/200] Batch 650/1987                 Loss D: 0.3238, Loss G: 2.2443
# Saved image: generatedimages\epoch_183_batch_650.png
# Epoch [183/200] Batch 700/1987                 Loss D: 0.4927, Loss G: 1.5818
# Saved image: generatedimages\epoch_183_batch_700.png
# Epoch [183/200] Batch 750/1987                 Loss D: 0.2934, Loss G: 1.7971
# Saved image: generatedimages\epoch_183_batch_750.png
# Epoch [183/200] Batch 800/1987                 Loss D: 0.3206, Loss G: 2.4931
# Saved image: generatedimages\epoch_183_batch_800.png
# Epoch [183/200] Batch 850/1987                 Loss D: 0.4663, Loss G: 1.8953
# Saved image: generatedimages\epoch_183_batch_850.png
# Epoch [183/200] Batch 900/1987                 Loss D: 0.4138, Loss G: 1.9637
# Saved image: generatedimages\epoch_183_batch_900.png
# Epoch [183/200] Batch 950/1987                 Loss D: 0.5969, Loss G: 1.5934
# Saved image: generatedimages\epoch_183_batch_950.png
# Epoch [183/200] Batch 1000/1987                 Loss D: 0.5241, Loss G: 1.5303
# Saved image: generatedimages\epoch_183_batch_1000.png
# Epoch [183/200] Batch 1050/1987                 Loss D: 0.3354, Loss G: 2.9556
# Saved image: generatedimages\epoch_183_batch_1050.png
# Epoch [183/200] Batch 1100/1987                 Loss D: 0.5186, Loss G: 2.2453
# Saved image: generatedimages\epoch_183_batch_1100.png
# Epoch [183/200] Batch 1150/1987                 Loss D: 0.4522, Loss G: 1.8588
# Saved image: generatedimages\epoch_183_batch_1150.png
# Epoch [183/200] Batch 1200/1987                 Loss D: 0.4599, Loss G: 2.4488
# Saved image: generatedimages\epoch_183_batch_1200.png
# Epoch [183/200] Batch 1250/1987                 Loss D: 0.3636, Loss G: 1.9093
# Saved image: generatedimages\epoch_183_batch_1250.png
# Epoch [183/200] Batch 1300/1987                 Loss D: 0.3471, Loss G: 2.2059
# Saved image: generatedimages\epoch_183_batch_1300.png
# Epoch [183/200] Batch 1350/1987                 Loss D: 0.5989, Loss G: 1.6510
# Saved image: generatedimages\epoch_183_batch_1350.png
# Epoch [183/200] Batch 1400/1987                 Loss D: 0.3599, Loss G: 1.7927
# Saved image: generatedimages\epoch_183_batch_1400.png
# Epoch [183/200] Batch 1450/1987                 Loss D: 0.4354, Loss G: 1.7147
# Saved image: generatedimages\epoch_183_batch_1450.png
# Epoch [183/200] Batch 1500/1987                 Loss D: 0.4440, Loss G: 1.4027
# Saved image: generatedimages\epoch_183_batch_1500.png
# Epoch [183/200] Batch 1550/1987                 Loss D: 0.3600, Loss G: 2.4216
# Saved image: generatedimages\epoch_183_batch_1550.png
# Epoch [183/200] Batch 1600/1987                 Loss D: 0.4020, Loss G: 2.1268
# Saved image: generatedimages\epoch_183_batch_1600.png
# Epoch [183/200] Batch 1650/1987                 Loss D: 0.5461, Loss G: 1.3339
# Saved image: generatedimages\epoch_183_batch_1650.png
# Epoch [183/200] Batch 1700/1987                 Loss D: 0.4638, Loss G: 1.6601
# Saved image: generatedimages\epoch_183_batch_1700.png
# Epoch [183/200] Batch 1750/1987                 Loss D: 0.4603, Loss G: 1.8126
# Saved image: generatedimages\epoch_183_batch_1750.png
# Epoch [183/200] Batch 1800/1987                 Loss D: 0.5021, Loss G: 1.9118
# Saved image: generatedimages\epoch_183_batch_1800.png
# Epoch [183/200] Batch 1850/1987                 Loss D: 0.5412, Loss G: 1.6277
# Saved image: generatedimages\epoch_183_batch_1850.png
# Epoch [183/200] Batch 1900/1987                 Loss D: 0.5384, Loss G: 1.7430
# Saved image: generatedimages\epoch_183_batch_1900.png
# Epoch [183/200] Batch 1950/1987                 Loss D: 0.5497, Loss G: 1.6854
# Saved image: generatedimages\epoch_183_batch_1950.png
# Epoch [184/200] Batch 0/1987                 Loss D: 0.4734, Loss G: 2.1263
# Saved image: generatedimages\epoch_184_batch_0.png
# Epoch [184/200] Batch 50/1987                 Loss D: 0.3934, Loss G: 2.0068
# Saved image: generatedimages\epoch_184_batch_50.png
# Epoch [184/200] Batch 100/1987                 Loss D: 0.4463, Loss G: 2.0963
# Saved image: generatedimages\epoch_184_batch_100.png
# Epoch [184/200] Batch 150/1987                 Loss D: 0.4801, Loss G: 2.2766
# Saved image: generatedimages\epoch_184_batch_150.png
# Epoch [184/200] Batch 200/1987                 Loss D: 0.3973, Loss G: 2.4016
# Saved image: generatedimages\epoch_184_batch_200.png
# Epoch [184/200] Batch 250/1987                 Loss D: 0.4429, Loss G: 1.5212
# Saved image: generatedimages\epoch_184_batch_250.png
# Epoch [184/200] Batch 300/1987                 Loss D: 0.5403, Loss G: 1.9946
# Saved image: generatedimages\epoch_184_batch_300.png
# Epoch [184/200] Batch 350/1987                 Loss D: 0.5155, Loss G: 1.8192
# Saved image: generatedimages\epoch_184_batch_350.png
# Epoch [184/200] Batch 400/1987                 Loss D: 0.3793, Loss G: 2.2230
# Saved image: generatedimages\epoch_184_batch_400.png
# Epoch [184/200] Batch 450/1987                 Loss D: 0.4153, Loss G: 2.3766
# Saved image: generatedimages\epoch_184_batch_450.png
# Epoch [184/200] Batch 500/1987                 Loss D: 0.6071, Loss G: 1.5495
# Saved image: generatedimages\epoch_184_batch_500.png
# Epoch [184/200] Batch 550/1987                 Loss D: 0.2938, Loss G: 2.0962
# Saved image: generatedimages\epoch_184_batch_550.png
# Epoch [184/200] Batch 600/1987                 Loss D: 0.3955, Loss G: 2.0292
# Saved image: generatedimages\epoch_184_batch_600.png
# Epoch [184/200] Batch 650/1987                 Loss D: 0.3783, Loss G: 1.6788
# Saved image: generatedimages\epoch_184_batch_650.png
# Epoch [184/200] Batch 700/1987                 Loss D: 0.3631, Loss G: 2.6482
# Saved image: generatedimages\epoch_184_batch_700.png
# Epoch [184/200] Batch 750/1987                 Loss D: 0.5402, Loss G: 1.4892
# Saved image: generatedimages\epoch_184_batch_750.png
# Epoch [184/200] Batch 800/1987                 Loss D: 0.4598, Loss G: 1.9302
# Saved image: generatedimages\epoch_184_batch_800.png
# Epoch [184/200] Batch 850/1987                 Loss D: 0.4170, Loss G: 2.2546
# Saved image: generatedimages\epoch_184_batch_850.png
# Epoch [184/200] Batch 900/1987                 Loss D: 0.4286, Loss G: 2.2089
# Saved image: generatedimages\epoch_184_batch_900.png
# Epoch [184/200] Batch 950/1987                 Loss D: 0.4667, Loss G: 1.7871
# Saved image: generatedimages\epoch_184_batch_950.png
# Epoch [184/200] Batch 1000/1987                 Loss D: 0.3690, Loss G: 2.1626
# Saved image: generatedimages\epoch_184_batch_1000.png
# Epoch [184/200] Batch 1050/1987                 Loss D: 0.3557, Loss G: 2.1282
# Saved image: generatedimages\epoch_184_batch_1050.png
# Epoch [184/200] Batch 1100/1987                 Loss D: 0.3935, Loss G: 1.9319
# Saved image: generatedimages\epoch_184_batch_1100.png
# Epoch [184/200] Batch 1150/1987                 Loss D: 0.5095, Loss G: 1.6835
# Saved image: generatedimages\epoch_184_batch_1150.png
# Epoch [184/200] Batch 1200/1987                 Loss D: 0.4113, Loss G: 1.8248
# Saved image: generatedimages\epoch_184_batch_1200.png
# Epoch [184/200] Batch 1250/1987                 Loss D: 0.5006, Loss G: 1.9660
# Saved image: generatedimages\epoch_184_batch_1250.png
# Epoch [184/200] Batch 1300/1987                 Loss D: 0.4451, Loss G: 1.8933
# Saved image: generatedimages\epoch_184_batch_1300.png
# Epoch [184/200] Batch 1350/1987                 Loss D: 0.6110, Loss G: 2.0318
# Saved image: generatedimages\epoch_184_batch_1350.png
# Epoch [184/200] Batch 1400/1987                 Loss D: 0.3746, Loss G: 2.3279
# Saved image: generatedimages\epoch_184_batch_1400.png
# Epoch [184/200] Batch 1450/1987                 Loss D: 0.5709, Loss G: 1.9053
# Saved image: generatedimages\epoch_184_batch_1450.png
# Epoch [184/200] Batch 1500/1987                 Loss D: 0.5010, Loss G: 1.6734
# Saved image: generatedimages\epoch_184_batch_1500.png
# Epoch [184/200] Batch 1550/1987                 Loss D: 0.3603, Loss G: 1.5804
# Saved image: generatedimages\epoch_184_batch_1550.png
# Epoch [184/200] Batch 1600/1987                 Loss D: 0.3564, Loss G: 2.2481
# Saved image: generatedimages\epoch_184_batch_1600.png
# Epoch [184/200] Batch 1650/1987                 Loss D: 0.4924, Loss G: 1.3801
# Saved image: generatedimages\epoch_184_batch_1650.png
# Epoch [184/200] Batch 1700/1987                 Loss D: 0.4338, Loss G: 1.7554
# Saved image: generatedimages\epoch_184_batch_1700.png
# Epoch [184/200] Batch 1750/1987                 Loss D: 0.3645, Loss G: 1.9836
# Saved image: generatedimages\epoch_184_batch_1750.png
# Epoch [184/200] Batch 1800/1987                 Loss D: 0.3985, Loss G: 1.9641
# Saved image: generatedimages\epoch_184_batch_1800.png
# Epoch [184/200] Batch 1850/1987                 Loss D: 0.4457, Loss G: 1.4335
# Saved image: generatedimages\epoch_184_batch_1850.png
# Epoch [184/200] Batch 1900/1987                 Loss D: 0.5635, Loss G: 1.9396
# Saved image: generatedimages\epoch_184_batch_1900.png
# Epoch [184/200] Batch 1950/1987                 Loss D: 0.6193, Loss G: 1.5492
# Saved image: generatedimages\epoch_184_batch_1950.png
# Epoch [185/200] Batch 0/1987                 Loss D: 0.4652, Loss G: 1.9526
# Saved image: generatedimages\epoch_185_batch_0.png
# Epoch [185/200] Batch 50/1987                 Loss D: 0.4379, Loss G: 2.0993
# Saved image: generatedimages\epoch_185_batch_50.png
# Epoch [185/200] Batch 100/1987                 Loss D: 0.3875, Loss G: 2.3950
# Saved image: generatedimages\epoch_185_batch_100.png
# Epoch [185/200] Batch 150/1987                 Loss D: 0.3777, Loss G: 2.2274
# Saved image: generatedimages\epoch_185_batch_150.png
# Epoch [185/200] Batch 200/1987                 Loss D: 0.3610, Loss G: 2.2649
# Saved image: generatedimages\epoch_185_batch_200.png
# Epoch [185/200] Batch 250/1987                 Loss D: 0.4873, Loss G: 1.8472
# Saved image: generatedimages\epoch_185_batch_250.png
# Epoch [185/200] Batch 300/1987                 Loss D: 0.4258, Loss G: 1.7470
# Saved image: generatedimages\epoch_185_batch_300.png
# Epoch [185/200] Batch 350/1987                 Loss D: 0.5236, Loss G: 2.2615
# Saved image: generatedimages\epoch_185_batch_350.png
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 23
#      21 lossG = criterion(output, torch.ones_like(output))
#      22 gen.zero_grad()
# ---> 23 lossG.backward()
#      24 opt_gen.step()
#      26 # Logging and saving images
#
# File c:\Users\srini\Desktop\python\cynaptics\.venv\Lib\site-packages\torch\_tensor.py:581, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     571 if has_torch_function_unary(self):
#     572     return handle_torch_function(
#     573         Tensor.backward,
#     574         (self,),
#    (...)
#     579         inputs=inputs,
#     580     )
# --> 581 torch.autograd.backward(
#     582     self, gradient, retain_graph, create_graph, inputs=inputs
#     583 )
#
# File c:\Users\srini\Desktop\python\cynaptics\.venv\Lib\site-packages\torch\autograd\__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File c:\Users\srini\Desktop\python\cynaptics\.venv\Lib\site-packages\torch\autograd\graph.py:825, in _engine_run_backward(t_outputs, *args, **kwargs)
#     823     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     824 try:
# --> 825     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     826         t_outputs, *args, **kwargs
#     827     )  # Calls into the C++ engine to run the backward pass
#     828 finally:
#     829     if attach_logging_hooks:
#
# KeyboardInterrupt:
